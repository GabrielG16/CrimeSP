# %%
import os
import pandas as pd
import geopandas as gpd

# %%
os.listdir()
# Out:
# ['Untitled.ipynb',
#  'DEINFO_DICIONARIO_DISTRITOS_2011_Variаveis.csv',
#  '.ipynb_checkpoints',
#  'DEINFO_DICIONARIO_DISTRITOS_2011_Arquivo.csv',
#  'DEINFO_METADADOS_DISTRITOS_2011.csv']

# %%
os.getcwd()
# Out:
# '/home/gabriel/Desktop/Projetos/CrimeSP/data/DISTRITO/CSV'

# %%
districts = gpd.read_file('../../DISTRITO_MUNICIPAL_SP_SMDUPolygon.shp')

# %%
districts.plot()
# Out:
# <AxesSubplot:>
